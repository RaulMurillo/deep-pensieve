# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
DIR = '../src/TensorFlow/train_results/'

FSIZE = (6, 4)

# %% [markdown]
# ### MNIST

# %%
SUBDIR = DIR+'lenet5/mnist/'

# , usecols=['val_loss', 'val_acc'])
float32_hist = pd.read_csv(SUBDIR+'float32.csv', header='infer')
# , usecols=['val_loss', 'val_acc'])
posit32_hist = pd.read_csv(SUBDIR+'posit32.csv', header='infer')
# , usecols=['val_loss', 'val_acc'])
posit16_hist = pd.read_csv(SUBDIR+'posit16.csv', header='infer')

float32_hist.index += 1  # Start at 1, after first epoch
posit32_hist.index += 1
posit16_hist.index += 1

float32_hist.head()
# Out:
#        loss       acc  val_loss  val_acc
# 1  0.265848  0.922967  0.069663   0.9783
# 2  0.065902  0.979933  0.045473   0.9847
# 3  0.046086  0.985317  0.036328   0.9888
# 4  0.036503  0.988100  0.031465   0.9893
# 5  0.030279  0.990017  0.033541   0.9891

# %%
fig, axis = plt.subplots(nrows=2, ncols=1,
                         sharex=True,
                         figsize=FSIZE
                         )
# colors = ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728', '#9467bd',
#           '#8c564b', '#e377c2', '#7f7f7f', '#bcbd22', '#17becf']
colors = ['#003f5c', '#bc5090', '#ffa600',]
markers = ['.', 'x', '*']


for i, df in enumerate([float32_hist, posit32_hist, posit16_hist]):
    # Plot
    df['loss'].plot(kind='line',
                    xlabel='Epoch',
                    ylabel='Loss',
                    ax=axis[0],
                    color=colors[i],
                    # marker=markers[i],
                    )
    df['val_acc'].plot(kind='line',
                       xlabel='Epoch',
                       ylabel='Test Accuracy',
                       ax=axis[1],
                       color=colors[i],
                    #    marker=markers[i],
                       )

# Some adjustments
axis[0].grid(zorder=0)
axis[1].grid(zorder=0)
# axis[0].set_ylim(bottom=0.0)
axis[1].set_ylim(top=0.995)
fig.tight_layout()

# Create a legend object for all subplots
handles, _ = axis[0].get_legend_handles_labels()
labels = ['Float32', 'Posit⟨32, 2⟩',
          'Posit⟨16, 1⟩']
fig.legend(handles, labels, title='Format',
           #    loc='upper center', bbox_to_anchor=(0.5, 1.1),
           #    ncol=len(labels)
           loc='upper center', bbox_to_anchor=(0.85, 0.95),
           ncol=1
           )

# save figure
plt.savefig('./mnist_training.pdf', bbox_inches='tight')

plt.show()

# %% [markdown]
# ### Fashion-MNIST

# %%
SUBDIR = DIR+'lenet5/fashion_mnist/'

# , usecols=['val_loss', 'val_acc'])
float32_hist = pd.read_csv(SUBDIR+'float32.csv', header='infer')
# , usecols=['val_loss', 'val_acc'])
posit32_hist = pd.read_csv(SUBDIR+'posit32.csv', header='infer')
# , usecols=['val_loss', 'val_acc'])
posit16_hist = pd.read_csv(SUBDIR+'posit16.csv', header='infer')

float32_hist.index += 1  # Start at 1, after first epoch
posit32_hist.index += 1
posit16_hist.index += 1

float32_hist.head()
# Out:
#        loss       acc  val_loss  val_acc
# 1  0.592165  0.788183  0.437817   0.8456
# 2  0.371710  0.866650  0.358818   0.8725
# 3  0.321094  0.884283  0.330748   0.8815
# 4  0.291216  0.893500  0.319936   0.8837
# 5  0.270199  0.901300  0.310261   0.8868

# %%
fig, axis = plt.subplots(nrows=2, ncols=1,
                         sharex=True,
                         figsize=FSIZE
                         )
# colors = ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728', '#9467bd',
#           '#8c564b', '#e377c2', '#7f7f7f', '#bcbd22', '#17becf']
colors = ['#003f5c', '#bc5090', '#ffa600',]


for i, df in enumerate([float32_hist, posit32_hist, posit16_hist]):
    # Plot
    df['loss'].plot(kind='line',
                    xlabel='Epoch',
                    ylabel='Loss',
                    ax=axis[0],
                    color=colors[i],
                    )
    df['val_acc'].plot(kind='line',
                       xlabel='Epoch',
                       ylabel='Test Accuracy',
                       ax=axis[1],
                       color=colors[i],
                       )

# Some adjustments
axis[0].grid(zorder=0)
axis[1].grid(zorder=0)
axis[0].set_ylim(bottom=0.0)
axis[1].set_ylim(top=0.92)
fig.tight_layout()

# Create a legend object for all subplots
handles, _ = axis[0].get_legend_handles_labels()
labels = ['Float32', 'Posit⟨32, 2⟩',
          'Posit⟨16, 1⟩']
fig.legend(handles, labels, title='Format',
           #    loc='upper center', bbox_to_anchor=(0.5, 1.1),
           #    ncol=len(labels)
           loc='upper center', bbox_to_anchor=(0.85, 0.95),
           ncol=1
           )

# save figure
plt.savefig('./fashion_mnist_training.pdf', bbox_inches='tight')

plt.show()

# %% [markdown]
# ### SVHN

# %%
SUBDIR = DIR+'SVHN/'

# , usecols=['val_loss', 'val_acc'])
float32_hist = pd.read_csv(SUBDIR+'float32.csv', header='infer')
# , usecols=['val_loss', 'val_acc'])
posit32_hist = pd.read_csv(SUBDIR+'posit32.csv', header='infer')
# , usecols=['val_loss', 'val_acc'])
posit16_hist = pd.read_csv(SUBDIR+'posit16.csv', header='infer')

float32_hist.index += 1  # Start at 1, after first epoch
posit32_hist.index += 1
posit16_hist.index += 1

float32_hist.head()
# Out:
#        loss       acc  val_loss   val_acc
# 1  0.907554  0.723521  0.566268  0.843961
# 2  0.416731  0.877582  0.457339  0.866549
# 3  0.316077  0.905907  0.441622  0.874962
# 4  0.248960  0.925755  0.396900  0.886447
# 5  0.192369  0.941030  0.415722  0.893362

# %%
fig, axis = plt.subplots(nrows=2, ncols=1,
                         sharex=True,
                         figsize=FSIZE
                         )
# colors = ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728', '#9467bd',
#           '#8c564b', '#e377c2', '#7f7f7f', '#bcbd22', '#17becf']
colors = ['#003f5c', '#bc5090', '#ffa600',]


for i, df in enumerate([float32_hist, posit32_hist, posit16_hist]):
    # Plot
    df['loss'].plot(kind='line',
                    xlabel='Epoch',
                    ylabel='Loss',
                    ax=axis[0],
                    color=colors[i],
                    )
    df['val_acc'].plot(kind='line',
                       xlabel='Epoch',
                       ylabel='Test Accuracy',
                       ax=axis[1],
                       color=colors[i],
                       )

# Some adjustments
axis[0].grid(zorder=0)
axis[1].grid(zorder=0)
# axis[0].set_ylim(bottom=0.0)
axis[1].set_ylim(top=0.92)
fig.tight_layout()

# Create a legend object for all subplots
handles, _ = axis[0].get_legend_handles_labels()
labels = ['Float32', 'Posit⟨32, 2⟩',
          'Posit⟨16, 1⟩']
fig.legend(handles, labels, title='Format',
           #    loc='upper center', bbox_to_anchor=(0.5, 1.1),
           #    ncol=len(labels)
           loc='upper center', bbox_to_anchor=(0.85, 0.95),
           ncol=1
           )

# save figure
plt.savefig('./svhn_training.pdf', bbox_inches='tight')

plt.show()

# %% [markdown]
# ### CIFAR-10

# %%
SUBDIR = DIR+'CIFAR10/'

# , usecols=['val_loss', 'val_acc'])
float32_hist = pd.read_csv(SUBDIR+'float32.csv', header='infer')
# , usecols=['val_loss', 'val_acc'])
posit32_hist = pd.read_csv(SUBDIR+'posit32.csv', header='infer')
# , usecols=['val_loss', 'val_acc'])
posit16_hist = pd.read_csv(SUBDIR+'posit16.csv', header='infer')

float32_hist.index += 1  # Start at 1, after first epoch
posit32_hist.index += 1
posit16_hist.index += 1

float32_hist.head()
# Out:
#        loss      acc  val_loss  val_acc
# 1  1.631449  0.45270  1.231329   0.5529
# 2  1.086106  0.61488  1.023762   0.6409
# 3  0.874871  0.69138  0.961964   0.6673
# 4  0.703162  0.75352  0.922752   0.6839
# 5  0.545366  0.81044  0.981923   0.6790

# %%
fig, axis = plt.subplots(nrows=2, ncols=1,
                         sharex=True,
                         figsize=FSIZE
                         )
# colors = ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728', '#9467bd',
#           '#8c564b', '#e377c2', '#7f7f7f', '#bcbd22', '#17becf']
colors = ['#003f5c', '#bc5090', '#ffa600',]


for i, df in enumerate([float32_hist, posit32_hist, posit16_hist]):
    # Plot
    df['loss'].plot(kind='line',
                    xlabel='Epoch',
                    ylabel='Loss',
                    ax=axis[0],
                    color=colors[i],
                    )
    df['val_acc'].plot(kind='line',
                       xlabel='Epoch',
                       ylabel='Test Accuracy',
                       ax=axis[1],
                       color=colors[i],
                       )

# Some adjustments
axis[0].grid(zorder=0)
axis[1].grid(zorder=0)
# axis[0].set_ylim(bottom=0.0)
axis[1].set_ylim(top=0.75)
fig.tight_layout()

# Create a legend object for all subplots
handles, _ = axis[0].get_legend_handles_labels()
labels = ['Float32', 'Posit⟨32, 2⟩',
          'Posit⟨16, 1⟩']
fig.legend(handles, labels, title='Format',
           #    loc='upper center', bbox_to_anchor=(0.5, 1.1),
           #    ncol=len(labels)
           loc='upper center', bbox_to_anchor=(0.85, 0.95),
           ncol=1
           )

# save figure
plt.savefig('./cifar_training.pdf', bbox_inches='tight')

plt.show()
